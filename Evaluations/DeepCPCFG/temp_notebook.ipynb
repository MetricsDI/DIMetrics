# %% [markdown]
# # Metrics Example on Tax Forms from 91 K1 NJ Tax forms
#
# ### In this notebook we compare the performance of CKY and a naive language model with no structured outputs (LayoutLM).
#
# ### We compure the metrics using our own code, currently titled DI Metrics

# %%
# General deps
import argparse, os
from glob import glob
from collections import OrderedDict
from tqdm import tqdm
import time
import ray
import numpy as np
import pandas as pd
import re

# %%
# Metric-implementations

from seqeval.metrics.sequence_labeling import get_entities #for resolving outputs from LayoutLM with no structured outputs
from metrics.metric_utils import (procCFG_XML,
                                  CFG_getdict_lists,
                                  json2dict, 
                                  xml2dict, 
                                  make_fields_list,
                                  compute_text_metrics,
                                  
                                 )

# %%
# start Ray instance
#count available cores and instance ray
num_cpus = len(os.sched_getaffinity(0))
ray.init(num_cpus= num_cpus, ignore_reinit_error=True)
# Out:
# 2021-05-06 19:43:29,040	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '10.143.86.53',
#  'raylet_ip_address': '10.143.86.53',
#  'redis_address': '10.143.86.53:6379',
#  'object_store_address': '/tmp/ray/session_2021-05-06_19-43-28_544399_33744/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-05-06_19-43-28_544399_33744/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2021-05-06_19-43-28_544399_33744',
#  'metrics_export_port': 65009,
#  'node_id': 'ba899cf3fa1b2b9c12ea701afe888a0c63e052ac88c42d66db5cc4d2'}

# %% [markdown]
# ## CKY Julia

# %%
parser = argparse.ArgumentParser()

parser.add_argument(
    "--gt_json_dir",
    type=str,
    default="/data/home/djonathan/ai-science-di-metrics/datasets/NJK1_91holdout_julia_2dCKY/data/test_nj/output/json/",
    help="Input directory containing list of json files",
)

parser.add_argument(
    "--preds_xml_dir",
    type=str,
    default="/data/home/djonathan/ai-science-di-metrics/datasets/NJK1_91holdout_julia_2dCKY/data/test_nj/output/xml/",
    help="Input directory containing list of json files",
)


args = parser.parse_args([])
args
# Out:
# Namespace(gt_json_dir='/data/home/djonathan/ai-science-di-metrics/datasets/NJK1_91holdout_julia_2dCKY/data/test_nj/output/json/', preds_xml_dir='/data/home/djonathan/ai-science-di-metrics/datasets/NJK1_91holdout_julia_2dCKY/data/test_nj/output/xml/')

# %%
#glob the files
gt_json_dir_files = sorted(glob(args.gt_json_dir+"*.json"))
preds_xml_dir_files = sorted(glob(args.preds_xml_dir+"*.xml"))
len(gt_json_dir_files), len(preds_xml_dir_files)
# Out:
# (91, 91)

# %%
# get the ground truths with parallel json parse (Lark Earley Parser + Ray)
#get xml files and convert them to dicts
gt_dicts_list = ray.get([json2dict.remote(f,verbose=False) for f in gt_json_dir_files])
preds_dicts = ray.get([xml2dict.remote(f,verbose=False) for f in preds_xml_dir_files]) 
field_names = make_fields_list(gt_dicts_list)      
assert len(gt_dicts_list) == len(preds_dicts)
field_names
# Out:
# ['NjTyEndDate',
#  'NjPartnerEin',
#  'NjPartnerName',
#  'NjPartnerAddress',
#  'NjPartnerCity',
#  'NjPartnerState',
#  'NjPartnerZip',
#  'NjPartnerEntityType',
#  'NjPartnerInterestPship',
#  'NjPartnershipEin',
#  'NjPartnershipName',
#  'NjPartnershipAddress',
#  'NjPartnershipCity',
#  'NjPartnershipState',
#  'NjPartnershipZip',
#  'NjProfitSharingI',
#  'NjProfitSharingIi',
#  'NjLossSharingI',
#  'NjLossSharingIi',
#  'NjCapitalOwnershipI',
#  'NjCapitalOwnershipIi',
#  'NjPartIiPshipIncomeA',
#  'NjPartIiPshipIncomeB',
#  'NjPartIiDistributiveShareA',
#  'NjPartIiDistributiveShareB',
#  'NjPartIiPartnerContributionA',
#  'NjPartIiPartnerContributionB',
#  'NjPartIiiNonresidentNjTax',
#  'NjTyStartDate',
#  'NjPartIiNetGuaranteedPmtsA',
#  'NjPartIiNetGuaranteedPmtsB']

# %%
gt_dicts_list
# Out:
# [{'NjTyEndDate': ',',
#   'NjPartnerEin': '13-3806691',
#   'NjPartnerName': 'BlackRock Financial Management, Inc.',
#   'NjPartnerAddress': '601 Union Street, 56th Floor',
#   'NjPartnerCity': 'Seattle',
#   'NjPartnerState': 'WA',
#   'NjPartnerZip': '98101',
#   'NjPartnerEntityType': 'FCG',
#   'NjPartnerInterestPship': '11 2017',
#   'NjPartnershipEin': '47-2367935',
#   'NjPartnershipName': '1893 Fund LLC',
#   'NjPartnershipAddress': '40 East 52nd Street',
#   'NjPartnershipCity': 'New York',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10022',
#   'NjProfitSharingI': '0.018108%',
#   'NjProfitSharingIi': '0.021000 %',
#   'NjLossSharingI': '0.018108%',
#   'NjLossSharingIi': '0.021000 %',
#   'NjCapitalOwnershipI': '0.020034%',
#   'NjCapitalOwnershipIi': '0.570258%',
#   'NjPartIiPshipIncomeA': '179,303',
#   'NjPartIiPshipIncomeB': '(2)',
#   'NjPartIiDistributiveShareA': '179,303',
#   'NjPartIiDistributiveShareB': '(2)'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '13-3806691',
#   'NjPartnerName': 'BLACKROCK FINANCIAL MANAGEMENT, INC.',
#   'NjPartnerAddress': '55 EAST 52ND STREET',
#   'NjPartnerCity': 'NEW YORK,,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10055',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnerInterestPship': '01/20/2015',
#   'NjPartnershipEin': '46-5515706',
#   'NjPartnershipName': 'LUMINEX TRADING & ANALYTICS LLC',
#   'NjPartnershipAddress': '157 SEAPORT BLVD., SUITE P3',
#   'NjPartnershipCity': 'BOSTON,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '4.876069 % 4.8689968',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '4.876069 % 4.8689968',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '4.900000 % 4.8999946',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '-252,867.',
#   'NjPartIiPshipIncomeB': '-26,969.',
#   'NjPartIiDistributiveShareA': '-252,867.',
#   'NjPartIiDistributiveShareB': '-26,969.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-0692629',
#   'NjPartnerName': 'hannover America private equity',
#   'NjPartnerAddress': 'PARTNERS II C/O TALANX GMBH ASSET & CO. KG MANAGEMENT GMBH',
#   'NjPartnerCity': 'KOLN (COLOGNE),',
#   'NjPartnerState': '50679',
#   'NjPartnerZip': 'GERMANY',
#   'NjPartnerInterestPship': '05/16/2017',
#   'NjPartnershipEin': '98-1368401',
#   'NjPartnershipName': 'OAKTREE SPECIAL SITUATIONS FUND',
#   'NjPartnershipAddress': '28TH FLOOR',
#   'NjPartnershipCity': 'LOS ANGELES,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '90071',
#   'NjProfitSharingI': '2.600219 %',
#   'NjProfitSharingIi': '2.638264 %',
#   'NjLossSharingI': '2.600219 %',
#   'NjLossSharingIi': '2.638264 %',
#   'NjCapitalOwnershipI': '1.598587 %',
#   'NjCapitalOwnershipIi': '1.662164 %',
#   'NjPartIiPartnerContributionA': 'of Assets as a Result of Complete Liquidation Part III Partner’s Information',
#   'NjPartIiPartnerContributionB': 'Line 19',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '98-1154107',
#   'NjPartnerName': 'HARBOURVEST GLOBAL ANNUAL PRIVATE EQUITY FUND',
#   'NjPartnerAddress': '190 ELGIN AVENUE',
#   'NjPartnerCity': 'GEORGETOWN,',
#   'NjPartnerState': 'CJ',
#   'NjPartnerZip': 'KY1-9005',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnershipEin': '98-1170109',
#   'NjPartnershipName': 'BAIN CAPITAL VENTURE FUND 2014, L.P.',
#   'NjPartnershipAddress': '200 CLARENDON STREET FL 41',
#   'NjPartnershipCity': 'BOSTON,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02116-5016',
#   'NjProfitSharingI': '0.881176%',
#   'NjProfitSharingIi': '1.154983%',
#   'NjLossSharingI': '1.154974%',
#   'NjLossSharingIi': '1.143155%',
#   'NjCapitalOwnershipI': '0.999833 %',
#   'NjCapitalOwnershipIi': '0.958799%',
#   'NjPartIiPshipIncomeA': '795,964',
#   'NjPartIiDistributiveShareA': '795,964'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-1154107',
#   'NjPartnerName': 'HARBOURVEST GLOBAL ANNUAL PRIVATE',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnershipEin': '27-3553169',
#   'NjPartnershipName': 'TPG VI DE AIV II, LP',
#   'NjPartnershipAddress': '301 COMMERCE STREET, SUITE 3300',
#   'NjPartnershipCity': 'FORT WORTH,',
#   'NjPartnershipState': 'TX',
#   'NjPartnershipZip': '76102',
#   'NjProfitSharingI': '0.014830 %',
#   'NjProfitSharingIi': '0.036172 %',
#   'NjLossSharingI': '0.014830 %',
#   'NjLossSharingIi': '0.036172 %',
#   'NjCapitalOwnershipI': '0.028251 %',
#   'NjCapitalOwnershipIi': '0.027064 %',
#   'NjPartIiPshipIncomeA': '24,470',
#   'NjPartIiPshipIncomeB': '(143)',
#   'NjPartIiDistributiveShareB': '(143)',
#   'NjPartIiiNonresidentNjTax': 'NONE'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***0699',
#   'NjPartnerName': 'HARBOURVEST 2015 GLOBAL FUND L.P.',
#   'NjPartnerAddress': '190 ELGIN AVENUE',
#   'NjPartnerCity': 'GEORGE TOWN, GRAND CAYMAN,',
#   'NjPartnerState': 'CJ',
#   'NjPartnerZip': 'KY1-9005',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnerInterestPship': '01/16/2018',
#   'NjPartnershipEin': '82-3267168',
#   'NjPartnershipName': 'THOMA BRAVO DISCOVER FUND AIV, L.P.',
#   'NjPartnershipAddress': '150 NORTH RIVERSIDE PLAZA SUITE 2800',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60606',
#   'NjProfitSharingI': '°.841455o/o',
#   'NjProfitSharingIi': '°.735656o/o',
#   'NjLossSharingI': '0.841455%',
#   'NjLossSharingIi': '0.735656%',
#   'NjCapitalOwnershipI': '0.786169%',
#   'NjCapitalOwnershipIi': '0.735656%',
#   'NjPartIiPshipIncomeA': '-99,942',
#   'NjPartIiPshipIncomeB': '-276',
#   'NjPartIiDistributiveShareA': '-99,942',
#   'NjPartIiDistributiveShareB': '-276'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-1210323',
#   'NjPartnerName': 'HARBOURVEST 2016 GLOBAL AIF L.P',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC, ONE',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnershipEin': '27-3553169',
#   'NjPartnershipName': 'TPG VI DE AIV II, LP',
#   'NjPartnershipAddress': '301 COMMERCE STREET, SUITE 3300',
#   'NjPartnershipCity': 'FORT WORTH,',
#   'NjPartnershipState': 'TX',
#   'NjPartnershipZip': '76102',
#   'NjProfitSharingI': '0.007607 %',
#   'NjProfitSharingIi': '0.018553 %',
#   'NjLossSharingI': '0.007607 %',
#   'NjLossSharingIi': '0.018553 %',
#   'NjCapitalOwnershipI': '0.013868 %',
#   'NjCapitalOwnershipIi': '0.013268 %',
#   'NjPartIiPshipIncomeA': '11,978',
#   'NjPartIiPshipIncomeB': '(70)',
#   'NjPartIiDistributiveShareB': '(70)',
#   'NjPartIiiNonresidentNjTax': 'NONE'},
#  {'NjTyStartDate': '1018',
#   'NjTyEndDate': '1231 20',
#   'NjPartnerEin': '82-3484395',
#   'NjPartnerName': 'HARBOURVEST AP7 PE INVESTMENT L.P.',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '01/18/2019',
#   'NjPartnershipEin': '84-3244274',
#   'NjPartnershipName': 'GTCR (CP-1) INVESTORS LP',
#   'NjPartnershipAddress': '300 NORTH LASALLE STREET SUITE 5600',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60654',
#   'NjProfitSharingI': '0 %',
#   'NjProfitSharingIi': '0.721021 %',
#   'NjLossSharingI': '0%',
#   'NjLossSharingIi': '°.721°21%',
#   'NjCapitalOwnershipI': '0 %',
#   'NjCapitalOwnershipIi': '0.721021 %',
#   'NjPartIiPshipIncomeA': '-14,237',
#   'NjPartIiPshipIncomeB': '72',
#   'NjPartIiDistributiveShareA': '-14,237',
#   'NjPartIiDistributiveShareB': '72',
#   'NjPartIiiNonresidentNjTax': '6'},
#  {'NjPartnerEin': '20-5587706',
#   'NjPartnerName': 'CALSTRS LOWER MIDDLE MARKET FUND III',
#   'NjPartnerAddress': 'ONE FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '06/21/2007',
#   'NjPartnershipEin': '20-5942619',
#   'NjPartnershipName': 'IRONWOOD MEZZANINE FUND II LP',
#   'NjPartnershipAddress': '45 NOD ROAD',
#   'NjPartnershipCity': 'AVON,',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06001',
#   'NjProfitSharingI': '6.9912609 % 6.9912609',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '6.9912609 % 6.9912609',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '6.9912311 % 6.9911764',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '773,723.',
#   'NjPartIiPshipIncomeB': '3,279.',
#   'NjPartIiDistributiveShareA': '773,723.',
#   'NjPartIiDistributiveShareB': '3,279.'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '*****2858',
#   'NjPartnerName': 'CONCORDIA RETIREMENT PLAN (B)',
#   'NjPartnerAddress': '1333 S. KIRKWOOD ROAD',
#   'NjPartnerCity': 'ST LOUIS,',
#   'NjPartnerState': 'MO',
#   'NjPartnerZip': '63122',
#   'NjPartnerEntityType': 'EFC',
#   'NjPartnerInterestPship': '12/27/2017',
#   'NjPartnershipEin': '82-3871376',
#   'NjPartnershipName': 'THOMA BRAVO FUND XII AIV, L.P.',
#   'NjPartnershipAddress': '150 NORTH RIVERSIDE PLAZA SUITE 2800',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60606',
#   'NjProfitSharingI': '0.181777%',
#   'NjProfitSharingIi': '0.172243%',
#   'NjLossSharingI': '0.181777%',
#   'NjLossSharingIi': '0.172243%',
#   'NjCapitalOwnershipI': '0.181777%',
#   'NjCapitalOwnershipIi': '0.172243%',
#   'NjPartIiPshipIncomeA': '18,230',
#   'NjPartIiPshipIncomeB': '983',
#   'NjPartIiDistributiveShareA': '18,230',
#   'NjPartIiDistributiveShareB': '983'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***2858',
#   'NjPartnerName': 'CONCORDIA RETIREMENT PLAN',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS ONE FINANCIAL CENTER',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'EFC',
#   'NjPartnerInterestPship': '01/01/2017',
#   'NjPartnershipEin': '81-3033294',
#   'NjPartnershipName': 'KLEINER PERKINS CAUFIELD & BYERS XVII, LLC',
#   'NjPartnershipAddress': '2750 SAND HILL ROAD',
#   'NjPartnershipCity': 'MENLO PARK,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94025',
#   'NjProfitSharingI': '0.568182%',
#   'NjProfitSharingIi': '0.568182%',
#   'NjLossSharingI': '0.568182%',
#   'NjLossSharingIi': '0.568182%',
#   'NjCapitalOwnershipI': '0.568183 0/ %',
#   'NjCapitalOwnershipIi': '0.568182%',
#   'NjPartIiPshipIncomeA': '-2,628',
#   'NjPartIiDistributiveShareA': '-2,628'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '61-1578321',
#   'NjPartnerName': 'HV CHARLOTTE US L.P',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnershipEin': '47-2533245',
#   'NjPartnershipName': 'LINDSAY GOLDBERG III - A AIV',
#   'NjPartnershipAddress': '630 FIFTH AVENUE, 30TH FLOOR',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10111',
#   'NjProfitSharingI': '5.699381 %',
#   'NjProfitSharingIi': 'NONE %',
#   'NjLossSharingI': '5.699381 %',
#   'NjLossSharingIi': '14.285855 %',
#   'NjCapitalOwnershipI': '7.991400 %',
#   'NjCapitalOwnershipIi': '2.776361 %',
#   'NjPartIiPshipIncomeA': '54,852',
#   'NjPartIiPshipIncomeB': '622',
#   'NjPartIiDistributiveShareB': '622',
#   'NjPartIiiNonresidentNjTax': '56'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***1676',
#   'NjPartnerName': 'HARBOURVEST DOVER STREET X INVESTMENT, LP',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '06/30/2019',
#   'NjPartnershipEin': '20-3923027',
#   'NjPartnershipName': 'KPCB PANDEMIC & BIO DEFENSE FUND, LLC',
#   'NjPartnershipAddress': '2750 SAND HILL ROAD',
#   'NjPartnershipCity': 'MENLO PARK,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94025',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.211382%',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.211382%',
#   'NjCapitalOwnershipI': 'O.OOOO00 <%',
#   'NjCapitalOwnershipIi': '0.211423%',
#   'NjPartIiPshipIncomeA': '-8,893',
#   'NjPartIiDistributiveShareA': '-8,893'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***1676',
#   'NjPartnerName': 'HARBOURVEST DOVER STREET X INVESTMENT, LP',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '06/30/2019',
#   'NjPartnershipEin': '20-4394579',
#   'NjPartnershipName': 'KLEINER PERKINS CAUFIELD & BYERS XII, LLC',
#   'NjPartnershipAddress': '2750 SAND HILL ROAD',
#   'NjPartnershipCity': 'MENLO PARK,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94025',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.625848%',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.625848%',
#   'NjCapitalOwnershipI': '0.000000 %',
#   'NjCapitalOwnershipIi': '0.000000%',
#   'NjPartIiPshipIncomeA': '-8,216',
#   'NjPartIiDistributiveShareA': '-8,216'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '45-2593305',
#   'NjPartnerName': 'DOVER STREET VIII L.P.',
#   'NjPartnerAddress': 'ONE FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '06/05/2015',
#   'NjPartnershipEin': '47-4199585',
#   'NjPartnershipName': 'SAGEVIEW CAPITAL PARTNERS II (ONSHORE), L.P.',
#   'NjPartnershipAddress': '55 RAILROAD AVE, 1ST FLOOR',
#   'NjPartnershipCity': 'GREENWICH,',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06830',
#   'NjProfitSharingI': '3.732991 %',
#   'NjProfitSharingIi': '4.561754 %',
#   'NjLossSharingI': 'NONE %',
#   'NjLossSharingIi': '4.561754 %',
#   'NjCapitalOwnershipI': '4.784034 %',
#   'NjCapitalOwnershipIi': '4.561754 %',
#   'NjPartIiPshipIncomeA': '41,095',
#   'NjPartIiPshipIncomeB': '37',
#   'NjPartIiDistributiveShareB': '37',
#   'NjPartIiiNonresidentNjTax': '3'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***8341',
#   'NjPartnerName': 'HARBOURVEST DOVER STREET IX INVESTMENT L.P.',
#   'NjPartnerAddress': '16 AVENUE PASTEUR',
#   'NjPartnerCity': 'LUXEMBOURG,',
#   'NjPartnerState': 'LU',
#   'NjPartnerZip': 'L-2310',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '10/28/2005',
#   'NjPartnershipEin': '20-3704876',
#   'NjPartnershipName': 'HIGHLAND CAPITAL PARTNERS VII L.P.',
#   'NjPartnershipAddress': 'ONE BROADWAY, 16TH FLOOR',
#   'NjPartnershipCity': 'CAMBRIDGE,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02142',
#   'NjProfitSharingI': '0.633823o/o',
#   'NjProfitSharingIi': '0.628024%',
#   'NjLossSharingI': '0.844622%',
#   'NjLossSharingIi': '0.844402%',
#   'NjCapitalOwnershipI': '0.620608 0/ %',
#   'NjCapitalOwnershipIi': '0.645594%',
#   'NjPartIiPshipIncomeA': '638,908',
#   'NjPartIiPshipIncomeB': '-3',
#   'NjPartIiDistributiveShareA': '638,908',
#   'NjPartIiDistributiveShareB': '-3'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-0330889',
#   'NjPartnerName': 'Harbourvest Dover Street IX Investment L.P.',
#   'NjPartnerAddress': '20, rue des Peupliers',
#   'NjPartnerCity': 'Luxembourg',
#   'NjPartnerState': 'L-2328',
#   'NjPartnerZip': 'Luxembourg',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '1 1 2018',
#   'NjPartnershipEin': '82-2861651',
#   'NjPartnershipName': 'Thomas H. Lee Equity Fund VIII, L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '0.420908%',
#   'NjProfitSharingIi': '0.139039%',
#   'NjLossSharingI': '0.420908%',
#   'NjLossSharingIi': '0.420772 %',
#   'NjCapitalOwnershipI': '0.420908%',
#   'NjCapitalOwnershipIi': '0.420287%',
#   'NjPartIiPshipIncomeA': '(156,331)',
#   'NjPartIiDistributiveShareA': '(156,331)'},
#  {'NjPartnerEin': '*****1621',
#   'NjPartnerName': 'DENSO HV PEP L.P.',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': '_NP_Q,,_',
#   'NjPartnerInterestPship': '_04/06/20191^',
#   'NjPartnershipEin': '98-1431721',
#   'NjPartnershipName': 'SUN CAPITAL PARTNERS VII, LP',
#   'NjPartnershipAddress': '5200 TOWN CENTER CIRCLE, 4TH FLOOR',
#   'NjPartnershipCity': 'BOCA RATON,',
#   'NjPartnershipState': 'FL',
#   'NjPartnershipZip': '33486',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.326084%',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.326084%',
#   'NjCapitalOwnershipI': 'O.OOOOOC^',
#   'NjCapitalOwnershipIi': '°.326°84O%',
#   'NjPartIiDistributiveShareB': 'cP.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '74-3234906',
#   'NjPartnerName': 'Dover Street VII, L.P.',
#   'NjPartnerAddress': 'c/o HarbourVest Partners, LLC One Financial Center, 44th Floor',
#   'NjPartnerCity': 'Boston',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '7 1 2011',
#   'NjPartnershipEin': '98-0494654',
#   'NjPartnershipName': 'Thomas H. Lee (Alternative) Parallel Fund VI, L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '0.332050%',
#   'NjProfitSharingIi': '0.268875%',
#   'NjLossSharingI': '0.332050%',
#   'NjLossSharingIi': '0.335949%',
#   'NjCapitalOwnershipI': '0.332050%',
#   'NjCapitalOwnershipIi': '0.332892%',
#   'NjPartIiPshipIncomeA': '305',
#   'NjPartIiDistributiveShareA': '305'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '74-3234906',
#   'NjPartnerName': 'Dover Street VII, L.P.',
#   'NjPartnerAddress': 'c/o HarbourVest Partners, LLC One Financial Center, 44th Floor',
#   'NjPartnerCity': 'Boston',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '4 28 2006',
#   'NjPartnershipEin': '20-4855225',
#   'NjPartnershipName': 'Thomas H. Lee Parallel Fund VI, L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '0.332410%',
#   'NjProfitSharingIi': '0.336009%',
#   'NjLossSharingI': '0.332410%',
#   'NjLossSharingIi': '0.272341 %',
#   'NjCapitalOwnershipI': '0.332410%',
#   'NjCapitalOwnershipIi': '0.391417%',
#   'NjPartIiPshipIncomeA': '72,632',
#   'NjPartIiDistributiveShareA': '72,632'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '45-2593305',
#   'NjPartnerName': 'DOVER STREET VIII L.P.',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '07/18/2011',
#   'NjPartnershipEin': '27-3569303',
#   'NjPartnershipName': 'GTCR FUND X/B LP',
#   'NjPartnershipAddress': '300 NORTH LASALLE STREET SUITE 5600',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60654',
#   'NjProfitSharingI': 'Â°.854031o/o',
#   'NjProfitSharingIi': '0.000000%',
#   'NjLossSharingI': '0.854031%',
#   'NjLossSharingIi': '0.000000%',
#   'NjCapitalOwnershipI': '0.8540310/ %',
#   'NjCapitalOwnershipIi': '0.000000%',
#   'NjPartIiPshipIncomeA': '-143,000',
#   'NjPartIiPshipIncomeB': '6,984',
#   'NjPartIiDistributiveShareA': '-143,000',
#   'NjPartIiDistributiveShareB': '6,984',
#   'NjPartIiiNonresidentNjTax': '629'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '45-2593305',
#   'NjPartnerName': 'DOVER street viii l.p.',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS LLC',
#   'NjPartnerCity': 'Part II',
#   'NjPartnerState': 'Final',
#   'NjPartnerZip': 'NJK-1',
#   'NjPartnerEntityType': 'NP ZIP Code',
#   'NjPartnerInterestPship': '05/16/2017',
#   'NjPartnershipEin': '98-1368401',
#   'NjPartnershipName': 'OAKTREE SPECIAL SITUATIONS FUND',
#   'NjPartnershipAddress': '28TH FLOOR',
#   'NjPartnershipCity': 'LOS ANGELES,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '90071',
#   'NjProfitSharingI': '1.468435 %',
#   'NjProfitSharingIi': '1.489922 %',
#   'NjLossSharingI': '1.468435 %',
#   'NjLossSharingIi': '1.489922 %',
#   'NjCapitalOwnershipI': '0.902780%',
#   'NjCapitalOwnershipIi': '0.938686 %',
#   'NjPartIiPartnerContributionA': 'of Assets as a Result of Complete Liquidation Part III Partner’s Information',
#   'NjPartIiPartnerContributionB': 'Line 19',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '98-1124623',
#   'NjPartnerName': 'MERANTI FUND LP',
#   'NjPartnerAddress': '190 ELGIN AVENUE',
#   'NjPartnerCity': 'GEORGE TOWN,',
#   'NjPartnerState': 'CJ',
#   'NjPartnerZip': 'KY1-9005',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnerInterestPship': '03/03/2016',
#   'NjPartnershipEin': '47-1687979',
#   'NjPartnershipName': 'MADISON DEARBORN CAPITAL PARTNERS VII-B, L.P.',
#   'NjPartnershipAddress': '70 WEST MADISON STREET SUITE 4600',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60602',
#   'NjProfitSharingI': '0.690611%',
#   'NjProfitSharingIi': '0.690611%',
#   'NjLossSharingI': '°.69°611%',
#   'NjLossSharingIi': '0.690611%',
#   'NjCapitalOwnershipI': '0.639060 0/ %',
#   'NjCapitalOwnershipIi': '0.631079%',
#   'NjPartIiPshipIncomeA': '-70,851',
#   'NjPartIiPshipIncomeB': '-941',
#   'NjPartIiDistributiveShareA': '-70,851',
#   'NjPartIiDistributiveShareB': '-941'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': 'Foreign Partner’s Name',
#   'NjPartnerName': 'City',
#   'NjPartnerAddress': 'Luxembourg,',
#   'NjPartnerCity': 'Peupliers State',
#   'NjPartnerState': 'LU',
#   'NjPartnerZip': 'L-2328',
#   'NjPartnershipEin': '82-4005992',
#   'NjPartnershipName': 'Year Member of Composite Return',
#   'NjPartnershipAddress': 'L.P.',
#   'NjPartnershipCity': 'State',
#   'NjPartnershipState': 'Zip',
#   'NjPartnershipZip': 'Code',
#   'NjProfitSharingI': 'or Termination 0.000000%',
#   'NjProfitSharingIi': '2.100527%',
#   'NjLossSharingI': '0.000000o%',
#   'NjLossSharingIi': '2.100527%',
#   'NjCapitalOwnershipI': '0.000000o%',
#   'NjCapitalOwnershipIi': '2.169514o/o',
#   'NjPartIiPshipIncomeA': '-3,704',
#   'NjPartIiDistributiveShareA': '-3,704'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***7363',
#   'NjPartnerName': 'HARBOURVEST PARTNERS X AIF BUYOUT L.P.',
#   'NjPartnerAddress': '20, RUE DES PEUPLIERS',
#   'NjPartnerCity': 'LUXEMBOURG,',
#   'NjPartnerState': 'LU',
#   'NjPartnerZip': 'L-2328',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnerInterestPship': '°1/16/2°18',
#   'NjPartnershipEin': '82-3267168',
#   'NjPartnershipName': 'THOMA BRAVO DISCOVER FUND AIV, L.P.',
#   'NjPartnershipAddress': '150 NORTH RIVERSIDE PLAZA SUITE 2800',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60606',
#   'NjProfitSharingI': '0.673164 %',
#   'NjProfitSharingIi': '0.588524%',
#   'NjLossSharingI': '0.673164%',
#   'NjLossSharingIi': '0.588524%',
#   'NjCapitalOwnershipI': '0.628934 0/ %',
#   'NjCapitalOwnershipIi': '0.588524%',
#   'NjPartIiPshipIncomeA': '-79,955',
#   'NjPartIiPshipIncomeB': '-220',
#   'NjPartIiDistributiveShareA': '-79,955',
#   'NjPartIiDistributiveShareB': '-220'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***6882',
#   'NjPartnerName': 'HARBOURVEST PARTNERS X VENTURE FUND L.P',
#   'NjPartnerAddress': 'ONE FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '01/04/2017',
#   'NjPartnershipEin': '81-1940038',
#   'NjPartnershipName': 'DCVC OPPORTUNITY FUND II, L.P.',
#   'NjPartnershipAddress': '270 UNIVERSITY AVENUE',
#   'NjPartnershipCity': 'PALO ALTO,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94301',
#   'NjProfitSharingI': '1.337838%',
#   'NjProfitSharingIi': ']..337838%',
#   'NjLossSharingI': '1.337838%',
#   'NjLossSharingIi': '1.337838%',
#   'NjCapitalOwnershipI': '1.337625%',
#   'NjCapitalOwnershipIi': ']..337538%',
#   'NjPartIiPshipIncomeA': '25,536',
#   'NjPartIiDistributiveShareA': '25,536'},
#  {'NjPartnerEin': '01-0682079',
#   'NjPartnerName': 'HARBOURVEST PARTNERS VII - VENTURE',
#   'NjPartnerAddress': 'L.P.',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '10/28/2003',
#   'NjPartnershipEin': '33-1073839',
#   'NjPartnershipName': 'DOMAIN PARTNERS VI LP',
#   'NjPartnershipAddress': '202 CARNEGIE CENTER, SUITE 104',
#   'NjPartnershipCity': 'PRINCETON,',
#   'NjPartnershipState': 'NJ',
#   'NjPartnershipZip': '08540',
#   'NjProfitSharingI': '5.0000000 %',
#   'NjProfitSharingIi': '5.0000000 %',
#   'NjLossSharingI': '5.0000000 %',
#   'NjLossSharingIi': '5.0000000 %',
#   'NjCapitalOwnershipI': '5.0000000 %',
#   'NjCapitalOwnershipIi': '5.0000000 %',
#   'NjPartIiPshipIncomeA': '-446,751.',
#   'NjPartIiDistributiveShareA': '-446,751.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '01-0682079',
#   'NjPartnerName': 'HarbourVest Partners VII-Venture Partnership Fund L.P.',
#   'NjPartnerAddress': '1 Financial Center 44th Floor',
#   'NjPartnerCity': 'Boston',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '9 30 2004',
#   'NjPartnershipEin': '38-3691084',
#   'NjPartnershipName': 'Wicks Communications & Media Partners III LP',
#   'NjPartnershipAddress': '400 Park Avenue, Suite 1210',
#   'NjPartnershipCity': 'New York',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10022',
#   'NjProfitSharingI': '5.230699%',
#   'NjProfitSharingIi': '0.000000%',
#   'NjLossSharingI': '5.230699%',
#   'NjLossSharingIi': '9.474901 %',
#   'NjCapitalOwnershipI': '9.314913%',
#   'NjCapitalOwnershipIi': '9.655450%',
#   'NjPartIiPshipIncomeA': '(144,352)',
#   'NjPartIiDistributiveShareA': '(144,352)'},
#  {'NjTyStartDate': 'Fiscal Y Beginning',
#   'NjTyEndDate': ',',
#   'NjPartnerEin': "Partnership's Federal EIN",
#   'NjPartnerName': "30-0791596 Partnership's Name",
#   'NjPartnerAddress': 'Holdings, LLC',
#   'NjPartnerCity': 'Boston',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': '20 Church',
#   'NjPartnershipEin': 'of:',
#   'NjPartnershipName': 'II',
#   'NjPartnershipAddress': '(ii) End of Year',
#   'NjPartnershipCity': 'Am ended NJK-1',
#   'NjPartnershipState': 'Income',
#   'NjPartnershipZip': 'Information',
#   'NjProfitSharingI': 'or Termination 0.621718 %',
#   'NjProfitSharingIi': '0.621580 %',
#   'NjLossSharingI': '0.621718 %',
#   'NjLossSharingIi': '0.621580 %',
#   'NjCapitalOwnershipI': '0.621718 %',
#   'NjCapitalOwnershipIi': '0.621580 %',
#   'NjPartIiPshipIncomeA': 'NONE',
#   'NjPartIiNetGuaranteedPmtsA': 'ayments',
#   'NjPartIiPartnerContributionA': 'NONE',
#   'NjPartIiDistributiveShareB': 'NONE NONE',
#   'NjPartIiiNonresidentNjTax': '1.'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '32-0292081',
#   'NjPartnerName': 'HARBOUR PARTNERS IX-CREDIT OPPORTUNITIES FUND',
#   'NjPartnerAddress': 'C/O HARBOURVEST PARTNERS, LLC ONE FINANCIAL',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '03/31/2014',
#   'NjPartnershipEin': '26-1274505',
#   'NjPartnershipName': 'MADISON DEARBORN CAPITAL PARTNERS VI-B, LP',
#   'NjPartnershipAddress': '70 WEST MADISON STREET SUITE 4600',
#   'NjPartnershipCity': 'CHICAGO,',
#   'NjPartnershipState': 'IL',
#   'NjPartnershipZip': '60602',
#   'NjProfitSharingI': '0.009841%',
#   'NjProfitSharingIi': '0.009841%',
#   'NjLossSharingI': '0.009841%',
#   'NjLossSharingIi': '0.009841%',
#   'NjCapitalOwnershipI': '0.008527%',
#   'NjCapitalOwnershipIi': '(Â°.008730%',
#   'NjPartIiPshipIncomeA': '42,350|',
#   'NjPartIiPshipIncomeB': '5,177',
#   'NjPartIiDistributiveShareA': '42,350',
#   'NjPartIiDistributiveShareB': '5,177',
#   'NjPartIiiNonresidentNjTax': '441'},
#  {'NjTyStartDate': 'Fiscal Y Beginning',
#   'NjTyEndDate': ',',
#   'NjPartnerEin': '320292081',
#   'NjPartnerName': 'HarbourVest Partners IX-Credit Opp',
#   'NjPartnerAddress': 'Financial Center',
#   'NjPartnerCity': 'State MA',
#   'NjPartnerState': '(see',
#   'NjPartnerZip': 'instructions)',
#   'NjPartnerInterestPship': '1',
#   'NjPartnershipEin': '30-0791596',
#   'NjPartnershipName': 'NDES Holdings, LLC',
#   'NjPartnershipAddress': '20 Church Street',
#   'NjPartnershipCity': '02111 Hartford',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06103',
#   'NjProfitSharingI': '(i) Before Decrease or Termination 0.311792 % (ii)',
#   'NjProfitSharingIi': 'End of Year 0.311723 %',
#   'NjLossSharingI': '0.311792 %',
#   'NjLossSharingIi': '0.311723 %',
#   'NjCapitalOwnershipI': '0.311792 %',
#   'NjCapitalOwnershipIi': '0.311723 %',
#   'NjPartIiPshipIncomeA': 'NONE',
#   'NjPartIiNetGuaranteedPmtsA': 'ayments',
#   'NjPartIiPartnerContributionA': 'NONE',
#   'NjPartIiDistributiveShareB': 'NONE NONE',
#   'NjPartIiiNonresidentNjTax': '1.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '32-0292081',
#   'NjPartnerName': 'HARBOURVEST PARTNERS IX-CREDIT',
#   'NjPartnerAddress': 'ONE FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '06/05/2015',
#   'NjPartnershipEin': '47-4199585',
#   'NjPartnershipName': 'SAGEVIEW CAPITAL PARTNERS II (ONSHORE), L.P.',
#   'NjPartnershipAddress': '55 RAILROAD AVE, 1ST FLOOR',
#   'NjPartnershipCity': 'GREENWICH,',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06830',
#   'NjProfitSharingI': '0.042742 %',
#   'NjProfitSharingIi': '0.052241 .%',
#   'NjLossSharingI': 'NONE %',
#   'NjLossSharingIi': '0.052241 .%',
#   'NjCapitalOwnershipI': '0.054787 %',
#   'NjCapitalOwnershipIi': '0.052241 .%',
#   'NjPartIiPshipIncomeA': '468',
#   'NjPartIiPshipIncomeB': '1',
#   'NjPartIiDistributiveShareB': '1'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '*****2079',
#   'NjPartnerName': 'HARBOURVEST PARTNERS IX-VENTURE FUND LP,',
#   'NjPartnerAddress': '1 FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '03/31/2011',
#   'NjPartnershipEin': '98-0692068',
#   'NjPartnershipName': 'BESSEMER VENTURE PARTNERS VIII INSTITUTIONAL,',
#   'NjPartnershipAddress': '1865 PALMER AVENUE SUITE 104',
#   'NjPartnershipCity': 'LARCHMONT,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10538',
#   'NjProfitSharingI': '2.824859%',
#   'NjProfitSharingIi': '2.824859%',
#   'NjLossSharingI': '2.824859%',
#   'NjLossSharingIi': '2.824859%',
#   'NjCapitalOwnershipI': '2.805380%',
#   'NjCapitalOwnershipIi': '2.830571%',
#   'NjPartIiPshipIncomeA': '2,157,485',
#   'NjPartIiDistributiveShareA': '2,157,485'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '54-2185640',
#   'NjPartnerName': 'Private Equity Managers (Concentrated) EMP LP',
#   'NjPartnerAddress': 'c/o Goldman Sachs & Co. 180 Maiden Lane, 37th Floor',
#   'NjPartnerCity': 'New York',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10038',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '2 27 2007',
#   'NjPartnershipEin': '20-8534269',
#   'NjPartnershipName': 'THL Equity Fund VI Intermediate Investors (Univision US), L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '1.681966%',
#   'NjProfitSharingIi': '1.691079 %',
#   'NjLossSharingI': '1.681966%',
#   'NjLossSharingIi': '1.691079 %',
#   'NjCapitalOwnershipI': '1.681966%',
#   'NjCapitalOwnershipIi': '1.681964 %',
#   'NjPartIiPshipIncomeA': '(396)',
#   'NjPartIiDistributiveShareA': '(396)'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '20-2193736',
#   'NjPartnerName': 'PRIVATE EQUITY PARTNERS 2004',
#   'NjPartnerAddress': 'GOLDMAN, SACHS & CO.',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10282',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '02/01/2006',
#   'NjPartnershipEin': '98-0462742',
#   'NjPartnershipName': 'VESTAR CAPITAL PARTNERS V, L.P.',
#   'NjPartnershipAddress': '245 PARK AVENUE, 41ST FLOOR',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10167',
#   'NjProfitSharingI': '0.090328 %',
#   'NjProfitSharingIi': '0.088398 %',
#   'NjLossSharingI': '0.090328 %',
#   'NjLossSharingIi': '0.088398 %',
#   'NjCapitalOwnershipI': '0.090858 %',
#   'NjCapitalOwnershipIi': '0.090200 %',
#   'NjPartIiPshipIncomeA': '170,950',
#   'NjPartIiPshipIncomeB': 'NONE',
#   'NjPartIiDistributiveShareB': 'NONE'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '26-1370937',
#   'NjPartnerName': 'PRIVATE EQUITY PARTNERS IX PMD QP LP C/O GSAM TAX DEF',
#   'NjPartnerAddress': '30 HUDSON STREET, 15TH FLOOR',
#   'NjPartnerCity': 'JERSEY CITY',
#   'NjPartnerState': 'NJ',
#   'NjPartnerZip': '07302',
#   'NjPartnerEntityType': 'RP',
#   'NjPartnerInterestPship': '5 13 2017',
#   'NjPartnershipEin': '82-1124497',
#   'NjPartnershipName': 'GRIDIRON ENERGY, LLC C/0 LS POWER DEVELOPMENT, LLC',
#   'NjPartnershipAddress': 'ONE TOWER CENTER 21ST FLOOR',
#   'NjPartnershipCity': 'EAST BRUNSWICK',
#   'NjPartnershipState': 'NJ',
#   'NjPartnershipZip': '08816',
#   'NjProfitSharingI': '0.058185%',
#   'NjProfitSharingIi': '0.058185 %',
#   'NjLossSharingI': '0.058185%',
#   'NjLossSharingIi': '0.058185 %',
#   'NjCapitalOwnershipI': '0.058185%',
#   'NjCapitalOwnershipIi': '0.058185 %',
#   'NjPartIiPshipIncomeA': '(22,122)',
#   'NjPartIiDistributiveShareA': '(22,122)'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-1167460',
#   'NjPartnerName': 'HIPEP VII SECONDARY L.P.',
#   'NjPartnerAddress': '190 ELGIN AVENUE GEORGE TOWN',
#   'NjPartnerCity': 'GRAND CAYMAN,',
#   'NjPartnerState': 'CJ',
#   'NjPartnerZip': 'KY1-9005',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnershipEin': '27-3553169',
#   'NjPartnershipName': 'TPG VI DE AIV II, LP',
#   'NjPartnershipAddress': '301 COMMERCE STREET, SUITE 3300',
#   'NjPartnershipCity': 'FORT WORTH,',
#   'NjPartnershipState': 'TX',
#   'NjPartnershipZip': '76102',
#   'NjProfitSharingI': '0.025145 %',
#   'NjProfitSharingIi': '0.061333 %',
#   'NjLossSharingI': '0.025145 %',
#   'NjLossSharingIi': '0.061333 %',
#   'NjCapitalOwnershipI': '0.046826 %',
#   'NjCapitalOwnershipIi': '0.044831 %',
#   'NjPartIiPshipIncomeA': '40,471',
#   'NjPartIiPshipIncomeB': '(233)',
#   'NjPartIiDistributiveShareB': '(233)',
#   'NjPartIiiNonresidentNjTax': 'NONE'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***6552',
#   'NjPartnerName': 'CRA FUND II, LLC',
#   'NjPartnerAddress': 'C/O BERKSHIRE PARTNERS, LLC 200 CLARENDON',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02116',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '01/27/2016',
#   'NjPartnershipEin': '81-1108044',
#   'NjPartnershipName': 'GENERAL CATALYST GROUP VIII - SUPPLEMENTAL,',
#   'NjPartnershipAddress': '20 UNIVERSITY ROAD, SUITE 450',
#   'NjPartnershipCity': 'CAMBRIDGE,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02138',
#   'NjProfitSharingI': '0.230455 <%',
#   'NjProfitSharingIi': '0.235970%',
#   'NjLossSharingI': '0.230455%',
#   'NjLossSharingIi': '0.235970%',
#   'NjCapitalOwnershipI': '0.213087%',
#   'NjCapitalOwnershipIi': '0.201473%',
#   'NjPartIiPshipIncomeA': '17',
#   'NjPartIiDistributiveShareA': '17'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '26-1486552',
#   'NjPartnerName': 'CRA FUND II, LLC',
#   'NjPartnerAddress': 'LLC',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02116',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '10/24/2013',
#   'NjPartnershipEin': '30-0798854',
#   'NjPartnershipName': 'RESOLUTE ANNEX I LP',
#   'NjPartnershipAddress': '548 MARKET ST. #26403',
#   'NjPartnershipCity': 'SAN FRANCISCO,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94104',
#   'NjProfitSharingI': '6.1660900 % 6.0592478',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '6.1660900 % 6.0592478',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '6.5307004 % 6.4953913',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '-89,266.',
#   'NjPartIiDistributiveShareA': '-89,266.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-0331524',
#   'NjPartnerName': 'kps-harbourvest multi-strategy fund l.p.',
#   'NjPartnerAddress': '190 ELGIN avenue',
#   'NjPartnerCity': 'GEORGE TOWN, GRAND CAYMAN KY1-9005',
#   'NjPartnerState': 'CAYMAN',
#   'NjPartnerZip': 'ISLAI',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '05/24/2019',
#   'NjPartnershipEin': '83-3170510',
#   'NjPartnershipName': 'GENSTAR CAPITAL PARTNERS IX, LP',
#   'NjPartnershipAddress': 'embarcadero center, SUITE 1900',
#   'NjPartnershipCity': 'SAN FRANCISCO,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94111',
#   'NjProfitSharingI': '0.000000 %',
#   'NjProfitSharingIi': '0 .071918 %',
#   'NjLossSharingI': '0.000000 %',
#   'NjLossSharingIi': '0 .071918 %',
#   'NjCapitalOwnershipI': '0.000000 %',
#   'NjCapitalOwnershipIi': '0 .047574 %'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '51-6574379',
#   'NjPartnerName': 'LAWRENCE PAGE TRII - DIVERSIFIED',
#   'NjPartnerAddress': 'FID TAX - CH I CAGO',
#   'NjPartnerCity': 'S',
#   'NjPartnerState': 'Final',
#   'NjPartnerZip': 'NJK-1',
#   'NjPartnerEntityType': 'ZIP',
#   'NjPartnerInterestPship': 'Code °5/18/2°00',
#   'NjPartnershipEin': '*****8851',
#   'NjPartnershipName': 'GOLDENTREE PARTNERS LP',
#   'NjPartnershipAddress': '300 PARK AVENUE, 21ST FLOOR',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10022',
#   'NjProfitSharingI': '0.041302 %',
#   'NjProfitSharingIi': '0.000000%',
#   'NjLossSharingI': '0.041302%',
#   'NjLossSharingIi': '0.000000%',
#   'NjCapitalOwnershipI': '0.041302 %',
#   'NjCapitalOwnershipIi': '0.000000%',
#   'NjPartIiPshipIncomeA': '87,079',
#   'NjPartIiPshipIncomeB': '119',
#   'NjPartIiPartnerContributionA': '4',
#   'NjPartIiDistributiveShareA': '87,083',
#   'NjPartIiDistributiveShareB': '119',
#   'NjPartIiiNonresidentNjTax': '11'},
#  {'NjPartnerEin': '*****3529',
#   'NjPartnerName': 'LTIC LLC',
#   'NjPartnerAddress': '100 JIM MORAN BOULEVARD',
#   'NjPartnerCity': 'DEERFIELD BEACH,',
#   'NjPartnerState': 'FL',
#   'NjPartnerZip': '33442',
#   'NjPartnerEntityType': 'FC',
#   'NjPartnerInterestPship': '02/28/2019',
#   'NjPartnershipEin': '98-1450551',
#   'NjPartnershipName': 'ABRY PARTNERS IX, LP',
#   'NjPartnershipAddress': '888 BOYLSTON STREET, SUITE 1600',
#   'NjPartnershipCity': 'BOSTON,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02199',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.000000%',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.946567%',
#   'NjCapitalOwnershipI': '0.000000 %',
#   'NjCapitalOwnershipIi': '0.927769%'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '*****3737',
#   'NjPartnerName': 'HVST-TOPE LLC',
#   'NjPartnerAddress': 'ONE FINANANCIAL CENTER 44TH FLOOR',
#   'NjPartnerCity': 'BOSTON,',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NO',
#   'NjPartnerInterestPship': '6/17/2011',
#   'NjPartnershipEin': '36-4704085',
#   'NjPartnershipName': 'RFE INVESTMENT PARTNERS VIII, L. P.',
#   'NjPartnershipAddress': '36 GROVE STREET',
#   'NjPartnershipCity': 'NEW CANAAN,',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06840',
#   'NjProfitSharingI': '9.639743 %',
#   'NjProfitSharingIi': '9.639741%',
#   'NjLossSharingI': '9.639743%',
#   'NjLossSharingIi': '9.639741%',
#   'NjCapitalOwnershipI': '12.049674 %',
#   'NjCapitalOwnershipIi': '12.049674%',
#   'NjPartIiPshipIncomeA': '104,994',
#   'NjPartIiDistributiveShareA': '104,994'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '47-2184367',
#   'NjPartnerName': 'HARBOURVEST REAL ASSETS-ENERGY FUND II L.P.',
#   'NjPartnerAddress': 'HARBOURVEST PARTNERS, LLC ONE FINANCIAL CENTER',
#   'NjPartnerCity': 'BOSTON',
#   'NjPartnerState': 'MA',
#   'NjPartnerZip': '02111',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11 2019',
#   'NjPartnershipEin': '98-0622443',
#   'NjPartnershipName': 'RESOURCE CAPITAL FUND V L.P. C/O RCF MANAGEMENT LLC',
#   'NjPartnershipAddress': '1400 SIXTEENTH STREET SUITE 200',
#   'NjPartnershipCity': 'DENVER',
#   'NjPartnershipState': 'CO',
#   'NjPartnershipZip': '80202',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.541032 %',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.541032 %',
#   'NjCapitalOwnershipI': '0.000000%',
#   'NjCapitalOwnershipIi': '0.530421 %',
#   'NjPartIiPshipIncomeA': '(500,913)',
#   'NjPartIiDistributiveShareA': '(500,913) pr'},
#  {'NjTyStartDate': 'Fiscal Y Beginning',
#   'NjTyEndDate': ',',
#   'NjPartnerEin': '814058448',
#   'NjPartnerName': 'HARBOURVEST REYNOLDS FUND I L.P.',
#   'NjPartnerAddress': 'FINANCIAL CENTER, 44TH FLOOR',
#   'NjPartnerCity': 'State MA',
#   'NjPartnerState': '(see',
#   'NjPartnerZip': 'instructions)',
#   'NjPartnerInterestPship': '1',
#   'NjPartnershipEin': '82-3456553',
#   'NjPartnershipName': 'REDPOINT OMEGA III, L.P.',
#   'NjPartnershipAddress': '3000 SAND HILL RD 2-290',
#   'NjPartnershipCity': '02111- MENLO PARK',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94025',
#   'NjProfitSharingI': '1.298700 %',
#   'NjProfitSharingIi': '1.298700 %',
#   'NjLossSharingI': '1.298700 %',
#   'NjLossSharingIi': '1.298700 %',
#   'NjCapitalOwnershipI': '1.298700 %',
#   'NjCapitalOwnershipIi': '1.298796 %',
#   'NjPartIiPshipIncomeA': '284,949.',
#   'NjPartIiDistributiveShareA': 'Income (loss) (Line 1',
#   'NjPartIiiNonresidentNjTax': '1.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': 'XX-XXX2713',
#   'NjPartnerName': 'STEPSTONE MAPLE OPPORTUNITIES FUND, L.P.',
#   'NjPartnerAddress': 'STEPSTONE GROUP LP UGLAND HOUSE, SOUTH CHURCH STR',
#   'NjPartnerCity': 'GEORGE TOWN',
#   'NjPartnerState': 'KY1-1104',
#   'NjPartnerZip': 'CAY',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11 2017',
#   'NjPartnershipEin': '98-1225649',
#   'NjPartnershipName': 'OAK HILL CAPITAL PARTNERS IV (ONSHORE) LP',
#   'NjPartnershipAddress': '263 TRESSER BOULEVARD, 15TH FLOOR',
#   'NjPartnershipCity': 'STAMFORD',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06901',
#   'NjProfitSharingI': '0.065367%',
#   'NjProfitSharingIi': '0.065367%',
#   'NjLossSharingI': '0.065367%',
#   'NjLossSharingIi': '0.065367%',
#   'NjCapitalOwnershipI': '0.061559%',
#   'NjCapitalOwnershipIi': '0.061912 %',
#   'NjPartIiPshipIncomeA': '(11,776)',
#   'NjPartIiPshipIncomeB': '(106)',
#   'NjPartIiDistributiveShareA': '(11,776)',
#   'NjPartIiDistributiveShareB': '(106)'},
#  {'NjPartnerEin': '20-1351488',
#   'NjPartnerName': 'STEPSTONE MEZZANINE PARTNERS I-A, LP',
#   'NjPartnerAddress': 'UNITS',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10013',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '09/01/2006',
#   'NjPartnershipEin': '20-5235943',
#   'NjPartnershipName': 'ITN ACQUISITION COMPANY, LLC',
#   'NjPartnershipAddress': '747 THIRD AVENUE',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10017',
#   'NjProfitSharingI': '0.4690191 % 0.4707761',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '0.4690191 % 0.4707761',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '0.5157813 % 0.5097788',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '-24,898.',
#   'NjPartIiDistributiveShareA': '-24,898.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '27-3444388',
#   'NjPartnerName': 'STEPSTONE OH SECONDARY',
#   'NjPartnerAddress': '4350 OPPORTUNITIES la jolla FUND, LP village drive',
#   'NjPartnerCity': 'SAN DIEGO,',
#   'NjPartnerState': 'CA',
#   'NjPartnerZip': '92122',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11/01/2012',
#   'NjPartnershipEin': '51-0627167',
#   'NjPartnershipName': 'OCM OPPORTUNITIES FUND VII AIF (DELAW,',
#   'NjPartnershipAddress': '28TH floor',
#   'NjPartnershipCity': 'LOS ANGELES,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '90071',
#   'NjProfitSharingI': '0.005612 %',
#   'NjProfitSharingIi': '0.005414 %',
#   'NjLossSharingI': '0.005612 %',
#   'NjLossSharingIi': '0.005414 %',
#   'NjCapitalOwnershipI': '0.005375%',
#   'NjCapitalOwnershipIi': '0.005336%',
#   'NjPartIiNetGuaranteedPmtsA': 'Line 19',
#   'NjPartIiNetGuaranteedPmtsB': 'Line19',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '27-3444388',
#   'NjPartnerName': 'STEPSTONE OH SECONDARY',
#   'NjPartnerAddress': '4350 OPPORTUNITIES la jolla FUND, LP village drive',
#   'NjPartnerCity': 'SAN DIEGO,',
#   'NjPartnerState': 'CA',
#   'NjPartnerZip': '92122',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11/01/2012',
#   'NjPartnershipEin': '98-0521250',
#   'NjPartnershipName': 'OCM OPPORTUNITIES FUND VII, L.P.',
#   'NjPartnershipAddress': '28TH floor',
#   'NjPartnershipCity': 'LOS ANGELES,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '90071',
#   'NjProfitSharingI': '0.005580%',
#   'NjProfitSharingIi': '0.005580%',
#   'NjLossSharingI': '0.005580%',
#   'NjLossSharingIi': '0.005580%',
#   'NjCapitalOwnershipI': '0.005509%',
#   'NjCapitalOwnershipIi': '0.005487%',
#   'NjPartIiNetGuaranteedPmtsA': 'Line 19',
#   'NjPartIiNetGuaranteedPmtsB': 'Line19',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '75-3240827',
#   'NjPartnerName': 'STEPSTONE PRIVATE EQUITY PARTNERS',
#   'NjPartnerAddress': 'UGLAND HOUSE',
#   'NjPartnerCity': 'GEORGE TOWN, GRAND CAYMAN,',
#   'NjPartnerState': 'KY',
#   'NjPartnerZip': 'KY1-1104',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '07/28/2006',
#   'NjPartnershipEin': '20-5898480',
#   'NjPartnershipName': 'PROVIDENCE EQUITY PARTNERS VI LP',
#   'NjPartnershipAddress': '50 KENNEDY PLAZA, 18TH FLOOR',
#   'NjPartnershipCity': 'PROVIDENCE,',
#   'NjPartnershipState': 'RI',
#   'NjPartnershipZip': '02903',
#   'NjProfitSharingI': '0.110119 %',
#   'NjProfitSharingIi': '0.110119 %',
#   'NjLossSharingI': '0.110119 %',
#   'NjLossSharingIi': '0.110119 %',
#   'NjCapitalOwnershipI': '0.107090 %',
#   'NjCapitalOwnershipIi': '0.107069 %',
#   'NjPartIiPshipIncomeA': '8,524'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '26-0139691',
#   'NjPartnerName': 'STEPSTONE PRIVATE EQUITY PARTNERS',
#   'NjPartnerAddress': '4275 EXECUTIVE SQUARE, SUITE 500',
#   'NjPartnerCity': 'LA JOLLA,',
#   'NjPartnerState': 'CA',
#   'NjPartnerZip': '92037',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '02/01/2007',
#   'NjPartnershipEin': '20-8419018',
#   'NjPartnershipName': 'PROVIDENCE EQUITY PARTNERS VI INTERNATIONAL LP',
#   'NjPartnershipAddress': '50 KENNEDY PLAZA, 18TH FLOOR',
#   'NjPartnershipCity': 'PROVIDENCE,',
#   'NjPartnershipState': 'RI',
#   'NjPartnershipZip': '02903',
#   'NjProfitSharingI': '0.066842 %',
#   'NjProfitSharingIi': '0.066842 %',
#   'NjLossSharingI': '0.066842 %',
#   'NjLossSharingIi': '0.066842 %',
#   'NjCapitalOwnershipI': '0.065485 %',
#   'NjCapitalOwnershipIi': '0.065532 %',
#   'NjPartIiPshipIncomeA': '191,318'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '90-0855009',
#   'NjPartnerName': 'STEPSTONE UWF SECONDARY',
#   'NjPartnerAddress': 'LP',
#   'NjPartnerCity': 'SAN DIEGO,',
#   'NjPartnerState': 'CA',
#   'NjPartnerZip': '92122',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '03/19/2010',
#   'NjPartnershipEin': '27-2134146',
#   'NjPartnershipName': 'HOUSATONIC EQUITY INVESTORS V, L.P.',
#   'NjPartnershipAddress': 'ONE POST STREET, SUITE 2600',
#   'NjPartnershipCity': 'SAN FRANCISCO,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94104-5203',
#   'NjProfitSharingI': '0.0826075 % 0.0826075',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '0.0826075 % 0.0826075',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '0.0885119 % 0.0862444',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '48,536.',
#   'NjPartIiPshipIncomeB': '128.',
#   'NjPartIiDistributiveShareA': '48,536.',
#   'NjPartIiDistributiveShareB': '128.'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '13-6275446',
#   'NjPartnerName': 'TR U/A FOR MARJORIE A MATHESON',
#   'NjPartnerAddress': 'FID TAX - CHICAGO',
#   'NjPartnerCity': 'S',
#   'NjPartnerState': 'Final',
#   'NjPartnerZip': 'NJK-1',
#   'NjPartnerEntityType': 'ZIP',
#   'NjPartnerInterestPship': 'Code 05/18/2000',
#   'NjPartnershipEin': '**-***8851',
#   'NjPartnershipName': 'GOLDENTREE PARTNERS LP',
#   'NjPartnershipAddress': '300 PARK AVENUE, 21ST FLOOR',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10022',
#   'NjProfitSharingI': '0.000591%',
#   'NjProfitSharingIi': '0.000000%',
#   'NjLossSharingI': 'O.OOO59^',
#   'NjLossSharingIi': '0.000000%',
#   'NjCapitalOwnershipI': '0.000591 %',
#   'NjCapitalOwnershipIi': '0.000000%',
#   'NjPartIiPshipIncomeA': '-11,150',
# ...
#   'NjLossSharingI': '0.543333 %',
#   'NjLossSharingIi': '0.543333 %',
#   'NjCapitalOwnershipI': '0.543333 %',
#   'NjCapitalOwnershipIi': '0.543333 %',
#   'NjPartIiPshipIncomeA': '(63,694)',
#   'NjPartIiPshipIncomeB': '(68)',
#   'NjPartIiDistributiveShareB': '(68)'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '34-2048005',
#   'NjPartnerName': 'Lexington partners vi holdings, lp',
#   'NjPartnerAddress': '660 madison avenue, 23rd floor',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10021',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '02/21/2006',
#   'NjPartnershipEin': '20-4380873',
#   'NjPartnershipName': 'ABERDEEN U.S. PRIVATE EQUITY III ,',
#   'NjPartnershipAddress': 'SUITE 200',
#   'NjPartnershipCity': 'PHILADELPHIA,',
#   'NjPartnershipState': 'PA',
#   'NjPartnershipZip': '19103',
#   'NjProfitSharingI': '1.454164 %',
#   'NjProfitSharingIi': '1.412524 %',
#   'NjLossSharingI': '0.000000 %',
#   'NjLossSharingIi': '1.412524 %',
#   'NjCapitalOwnershipI': '0.159893 %',
#   'NjCapitalOwnershipIi': '1.387838 %',
#   'NjPartIiPshipIncomeA': '304,544',
#   'NjPartIiPshipIncomeB': '293',
#   'NjPartIiDistributiveShareB': '293'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '34-2048005',
#   'NjPartnerName': 'LEXINGTON CAPITAL PARTNERS VI',
#   'NjPartnerAddress': '660 MADISON AVENUE, 23RD FLOOR',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10021',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '02/01/2006',
#   'NjPartnershipEin': '98-0462742',
#   'NjPartnershipName': 'VESTAR CAPITAL PARTNERS V, L.P.',
#   'NjPartnershipAddress': '245 PARK AVENUE, 41ST FLOOR',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10167',
#   'NjProfitSharingI': '2.112552 %',
#   'NjProfitSharingIi': '2.067382 %',
#   'NjLossSharingI': '2.112552 %',
#   'NjLossSharingIi': '2.067382 %',
#   'NjCapitalOwnershipI': '2.124928 %',
#   'NjCapitalOwnershipIi': '2.109526 %',
#   'NjPartIiPshipIncomeA': '3,998,026',
#   'NjPartIiPshipIncomeB': 'NONE',
#   'NjPartIiDistributiveShareB': 'NONE'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '20-1117062',
#   'NjPartnerName': 'LEXINGTON MIDDLE MARKET INVESTORS',
#   'NjPartnerAddress': '660 MADISON AVENUE',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10021',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnershipEin': '03-0609553',
#   'NjPartnershipName': 'TAILWIND CAPITAL PARTNERS LP',
#   'NjPartnershipAddress': '485 LEXINGTON AVENUE',
#   'NjPartnershipCity': 'NEW YORK,',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10017',
#   'NjProfitSharingI': '1.129829 %',
#   'NjProfitSharingIi': '1.043223 %',
#   'NjLossSharingI': '1.129829 %',
#   'NjLossSharingIi': '1.043223 %',
#   'NjCapitalOwnershipI': '1.097226 %',
#   'NjCapitalOwnershipIi': '1.120918 %',
#   'NjPartIiPshipIncomeA': '1,153',
#   'NjPartIiPshipIncomeB': '134',
#   'NjPartIiDistributiveShareB': '134',
#   'NjPartIiiNonresidentNjTax': '12'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '83-2871291',
#   'NjPartnerName': 'LEXINGTON PRIVATE EQUITY 26, L.P.',
#   'NjPartnerAddress': '660 MADISON AVENUE',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10065',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '08/13/2004',
#   'NjPartnershipEin': '20-1579234',
#   'NjPartnershipName': 'PROVIDENCE EQUITY PARTNERS V LP',
#   'NjPartnershipAddress': '50 KENNEDY PLAZA, 18TH FLOOR',
#   'NjPartnershipCity': 'PROVIDENCE,',
#   'NjPartnershipState': 'RI',
#   'NjPartnershipZip': '02903',
#   'NjProfitSharingI': 'NONE %',
#   'NjProfitSharingIi': '0.951700 %',
#   'NjLossSharingI': 'NONE %',
#   'NjLossSharingIi': '0.951700 %',
#   'NjCapitalOwnershipI': 'NONE %',
#   'NjCapitalOwnershipIi': '0.921978 %',
#   'NjPartIiPshipIncomeA': '414'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '20-2186419',
#   'NjPartnerName': 'CARDINAL FUND I, L.P.',
#   'NjPartnerAddress': '201 MAIN STREET, SUITE 1000',
#   'NjPartnerCity': 'FORT WORTH',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '10 6 2006',
#   'NjPartnershipEin': '20-5721263',
#   'NjPartnershipName': 'LS POWER EQUITY PARTNERS II LP c/o LS Power Development,',
#   'NjPartnershipAddress': '1700 BROADWAY, 35th FLOOR',
#   'NjPartnershipCity': 'NEW YORK',
#   'NjPartnershipState': 'NY',
#   'NjPartnershipZip': '10019',
#   'NjProfitSharingI': '0.221996%',
#   'NjProfitSharingIi': '0.223831 %',
#   'NjLossSharingI': '0.221*6%',
#   'NjLossSharingIi': '0.223831 %',
#   'NjCapitalOwnershipI': '0.199892%',
#   'NjCapitalOwnershipIi': '0.195967%',
#   'NjPartIiPartnerContributionA': 'Complete Liquidation',
#   'NjPartIiPartnerContributionB': "Part III Partner's Information",
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '46-0923191',
#   'NjPartnerName': 'Lexington gemstone holdings',
#   'NjPartnerAddress': '(A), 660 L.P. madison avenue',
#   'NjPartnerCity': 'NEW YORK,',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10065',
#   'NjPartnerInterestPship': '12/31/2012',
#   'NjPartnershipEin': '20-2998535',
#   'NjPartnershipName': 'OCM OPPORTUNITIES FUND VI, L.P.',
#   'NjPartnershipAddress': '28TH FLOOR',
#   'NjPartnershipCity': 'LOS ANGELES,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '90071',
#   'NjProfitSharingI': '0.282472 %',
#   'NjProfitSharingIi': '0.282432 %',
#   'NjLossSharingI': '0.282472 %',
#   'NjLossSharingIi': '0.282432 %',
#   'NjCapitalOwnershipI': '0.224657 %',
#   'NjCapitalOwnershipIi': '0.224314 %',
#   'NjPartIiPartnerContributionA': 'Complete Liquidation',
#   'NjPartIiPartnerContributionB': 'Part III Partner’s Information',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '46-0923191',
#   'NjPartnerName': 'Lexington Gemstone Holdings A, L.P.',
#   'NjPartnerAddress': '660 Madison Avenue 23rd Floor',
#   'NjPartnerCity': 'New York',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10065',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '9 30 2012',
#   'NjPartnershipEin': '20-4844400',
#   'NjPartnershipName': 'Thomas H. Lee Equity Fund VI, L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '0.225540%',
#   'NjProfitSharingIi': '0.183862%',
#   'NjLossSharingI': '0.225540%',
#   'NjLossSharingIi': '0.225238%',
#   'NjCapitalOwnershipI': '0.225540%',
#   'NjCapitalOwnershipIi': '0.265641 %',
#   'NjPartIiPshipIncomeA': '70,570',
#   'NjPartIiDistributiveShareA': '70,570'},
#  {'NjTyStartDate': 'Fiscal Y Beginning',
#   'NjTyEndDate': ',',
#   'NjPartnerEin': '320476681',
#   'NjPartnerName': 'JASPER RIDGE PRIVATE',
#   'NjPartnerAddress': 'MAIN STREET, SUITE 1000 State',
#   'NjPartnerCity': '(see inst',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': 'ructions)',
#   'NjPartnerEntityType': 'gan:',
#   'NjPartnerInterestPship': '[',
#   'NjPartnershipEin': '980574854',
#   'NjPartnershipName': 'MONITOR CLIPPER EQUITY PARTNERS II',
#   'NjPartnershipAddress': '116 HUNTINGTON AVENUE, 9TH FLOOR',
#   'NjPartnershipCity': '__| IMe^ber of',
#   'NjPartnershipState': 'Composite',
#   'NjPartnershipZip': 'Return',
#   'NjProfitSharingI': 'or Termination',
#   'NjProfitSharingIi': '0.609092 %',
#   'NjLossSharingI': '0.609092',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '0.508932',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '-327,196.',
#   'NjPartIiNetGuaranteedPmtsA': 'ayments',
#   'NjPartIiDistributiveShareA': '-327,196.',
#   'NjPartIiiNonresidentNjTax': '1.'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': 'XX-XXX1444',
#   'NjPartnerName': 'JASPER RIDGE DIVERSIFIED, L.P.',
#   'NjPartnerAddress': '201 MAIN STREET SUITE 1000',
#   'NjPartnerCity': 'FORT WORTH',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11 2015',
#   'NjPartnershipEin': '98-1225649',
#   'NjPartnershipName': 'OAK HILL CAPITAL PARTNERS IV (ONSHORE) LP',
#   'NjPartnershipAddress': '263 TRESSER BOULEVARD, 15TH FLOOR',
#   'NjPartnershipCity': 'STAMFORD',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06901',
#   'NjProfitSharingI': '0.234456%',
#   'NjProfitSharingIi': '0.234456%',
#   'NjLossSharingI': '0.234456%',
#   'NjLossSharingIi': '0.234456%',
#   'NjCapitalOwnershipI': '0.222885%',
#   'NjCapitalOwnershipIi': '0.223317%',
#   'NjPartIiPshipIncomeA': '(42,235)',
#   'NjPartIiPshipIncomeB': '(379)',
#   'NjPartIiDistributiveShareA': '(42,235)',
#   'NjPartIiDistributiveShareB': '(379)'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': 'XX-XXX6419',
#   'NjPartnerName': 'TERREBONNE INVESTMENTS, L.P.',
#   'NjPartnerAddress': '201 MAIN STREET SUITE 1000',
#   'NjPartnerCity': 'FORT WORTH',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'NO',
#   'NjPartnerInterestPship': '11 2015',
#   'NjPartnershipEin': '98-1225649',
#   'NjPartnershipName': 'OAK HILL CAPITAL PARTNERS IV (ONSHORE) LP',
#   'NjPartnershipAddress': '263 TRESSER BOULEVARD, 15TH FLOOR',
#   'NjPartnershipCity': 'STAMFORD',
#   'NjPartnershipState': 'CT',
#   'NjPartnershipZip': '06901',
#   'NjProfitSharingI': '0.535362%',
#   'NjProfitSharingIi': '0.535363%',
#   'NjLossSharingI': '0.535362%',
#   'NjLossSharingIi': '0.535363%',
#   'NjCapitalOwnershipI': '0.508941%',
#   'NjCapitalOwnershipIi': '0.509928%',
#   'NjPartIiPshipIncomeA': '(96,442)',
#   'NjPartIiPshipIncomeB': '(866)',
#   'NjPartIiDistributiveShareA': '(96,442)',
#   'NjPartIiDistributiveShareB': '(866)'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***1035',
#   'NjPartnerName': 'PINEBRIDGE SECONDARY PARTNERS IV , SLP',
#   'NjPartnerAddress': '2 RUE JEAN MONNNET',
#   'NjPartnerCity': 'GRAND DUCHY OF LUXEMBOURG, LU',
#   'NjPartnerState': 'L-',
#   'NjPartnerZip': '2180',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnershipEin': '83-2753786',
#   'NjPartnershipName': 'NCP ROADONE CO-INVEST, LP',
#   'NjPartnershipAddress': '888 BOYLSTON STREET, SUITE 1100 C/O NONANTUM',
#   'NjPartnershipCity': 'BOSTON,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02199',
#   'NjProfitSharingI': '14.937249%',
#   'NjProfitSharingIi': '14.801313%',
#   'NjLossSharingI': '14.937249%',
#   'NjLossSharingIi': '14.801313%',
#   'NjCapitalOwnershipI': '14.936967%',
#   'NjCapitalOwnershipIi': '14.941576%',
#   'NjPartIiPshipIncomeA': '-93,676',
#   'NjPartIiPshipIncomeB': '-1,673',
#   'NjPartIiDistributiveShareA': '-93,676',
#   'NjPartIiDistributiveShareB': '-1,673'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '98-1025781',
#   'NjPartnerName': 'PvE Investors I-C, L.P.',
#   'NjPartnerAddress': '201 Main Street, Suite 1000',
#   'NjPartnerCity': 'Fort Worth',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'MP',
#   'NjPartnerInterestPship': '12 2015',
#   'NjPartnershipEin': '27-4903823',
#   'NjPartnershipName': 'Polaris Venture Partners V AIV, L.P.',
#   'NjPartnershipAddress': 'One Marina Park Drive, 10th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02210',
#   'NjProfitSharingI': '0.804373%',
#   'NjProfitSharingIi': '0.804614%',
#   'NjLossSharingI': '0.804373%',
#   'NjLossSharingIi': '0.804614%',
#   'NjCapitalOwnershipI': '0.804373%',
#   'NjCapitalOwnershipIi': '0.804614%',
#   'NjPartIiPshipIncomeA': '31,237',
#   'NjPartIiPshipIncomeB': '394',
#   'NjPartIiDistributiveShareA': '31,237',
#   'NjPartIiDistributiveShareB': '394'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '20-2186419',
#   'NjPartnerName': 'Terrebonne Investments, L.P.',
#   'NjPartnerAddress': '201 Main Street, Suite 1000',
#   'NjPartnerCity': 'Fort Worth',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'MP',
#   'NjPartnerInterestPship': '12 2015',
#   'NjPartnershipEin': '27-4903823',
#   'NjPartnershipName': 'Polaris Venture Partners V AIV, L.P.',
#   'NjPartnershipAddress': 'One Marina Park Drive, 10th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02210',
#   'NjProfitSharingI': '0.673874%',
#   'NjProfitSharingIi': '0.674076 %',
#   'NjLossSharingI': '0.673874%',
#   'NjLossSharingIi': '0.674076 %',
#   'NjCapitalOwnershipI': '0.673874%',
#   'NjCapitalOwnershipIi': '0.674076%',
#   'NjPartIiPshipIncomeA': '26,167',
#   'NjPartIiPshipIncomeB': '330',
#   'NjPartIiDistributiveShareA': '26,167',
#   'NjPartIiDistributiveShareB': '330'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '83-1263565',
#   'NjPartnerName': 'Beehive Secondary Partners, LP',
#   'NjPartnerAddress': '399 Park Avenue, 4th Floor',
#   'NjPartnerCity': 'New York',
#   'NjPartnerState': 'NY',
#   'NjPartnerZip': '10022',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '4 1 2019',
#   'NjPartnershipEin': '27-4903823',
#   'NjPartnershipName': 'Polaris Venture Partners V AIV, L.P.',
#   'NjPartnershipAddress': 'One Marina Park Drive, 10th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02210',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '0.148884%',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '0.148884%',
#   'NjCapitalOwnershipI': '0.000000%',
#   'NjCapitalOwnershipIi': '0.148884%',
#   'NjPartIiPshipIncomeA': '4,317',
#   'NjPartIiPshipIncomeB': '55',
#   'NjPartIiDistributiveShareA': '4,317',
#   'NjPartIiDistributiveShareB': '55'},
#  {'NjTyEndDate': 'December 31',
#   'NjPartnerEin': '98-1284597',
#   'NjPartnerName': 'StepStone H Opportunities Fund L.P.',
#   'NjPartnerAddress': 'Ugland House, South Church Street',
#   'NjPartnerCity': 'George Town',
#   'NjPartnerState': 'KY1-1104',
#   'NjPartnerZip': 'Caymar',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '12 2019',
#   'NjPartnershipEin': '83-2869472',
#   'NjPartnershipName': 'THL Equity Fund VIII Investors (Agiliti), L.P.',
#   'NjPartnershipAddress': 'c/o Thomas H. Lee Partners, L.P. 100 Federal Street, 35th Floor',
#   'NjPartnershipCity': 'Boston',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02110',
#   'NjProfitSharingI': '0.000000%',
#   'NjProfitSharingIi': '11.322813 %',
#   'NjLossSharingI': '0.000000%',
#   'NjLossSharingIi': '11.324171%',
#   'NjCapitalOwnershipI': '0.000000%',
#   'NjCapitalOwnershipIi': '11.322811 %',
#   'NjPartIiPshipIncomeA': '1,479,464',
#   'NjPartIiDistributiveShareA': '1,479,464'},
#  {'NjTyEndDate': '.,',
#   'NjPartnerEin': '**-***1444',
#   'NjPartnerName': 'JASPER RIDGE DIVERSIFIED, L.P.',
#   'NjPartnerAddress': '201 N. MAIN ST., SUITE 1000',
#   'NjPartnerCity': 'FORT WORTH,',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '05/29/2014',
#   'NjPartnershipEin': '46-5728474',
#   'NjPartnershipName': 'TA XI DO AIV, L.P.',
#   'NjPartnershipAddress': '200 CLARENDON STREET, 56TH FLOOR',
#   'NjPartnershipCity': 'BOSTON,',
#   'NjPartnershipState': 'MA',
#   'NjPartnershipZip': '02116',
#   'NjProfitSharingI': '0.079375%',
#   'NjProfitSharingIi': '0.079141%',
#   'NjLossSharingI': '0.079375%',
#   'NjLossSharingIi': '0.079141%',
#   'NjCapitalOwnershipI': '0.079281 %',
#   'NjCapitalOwnershipIi': '0.079440%',
#   'NjPartIiPshipIncomeA': '7,568',
#   'NjPartIiPshipIncomeB': '-42',
#   'NjPartIiPartnerContributionA': "of Assets as a Result of Complete Liquidation Part III Partner's Information",
#   'NjPartIiPartnerContributionB': 'Line 19',
#   'NjPartIiDistributiveShareB': 'Page'},
#  {'NjTyEndDate': ',',
#   'NjPartnerEin': '36-4836115',
#   'NjPartnerName': 'JRP PROJECT PRESIDIO ACQUISITION, LP',
#   'NjPartnerAddress': '201 MAIN STREET, SUITE 1000',
#   'NjPartnerCity': 'FORT WORTH,',
#   'NjPartnerState': 'TX',
#   'NjPartnerZip': '76102',
#   'NjPartnerEntityType': 'NP',
#   'NjPartnerInterestPship': '11/09/2005',
#   'NjPartnershipEin': '20-3769477',
#   'NjPartnershipName': 'TCV VI, L.P.',
#   'NjPartnershipAddress': '250 MIDDLEFIELD ROAD',
#   'NjPartnershipCity': 'MENLO PARK,',
#   'NjPartnershipState': 'CA',
#   'NjPartnershipZip': '94025',
#   'NjProfitSharingI': '0.1655882 % 0.1656096',
#   'NjProfitSharingIi': '%',
#   'NjLossSharingI': '0.1655882 % 0.1656096',
#   'NjLossSharingIi': '%',
#   'NjCapitalOwnershipI': '0.1655882 % 0.1656096',
#   'NjCapitalOwnershipIi': '%',
#   'NjPartIiPshipIncomeA': '2,977.',
#   'NjPartIiDistributiveShareA': '2,977.'}]

# %%
a = CFG_getdict_lists(gt_dicts_list,preds_dicts,field_names)
compute_text_metrics(a,field_names)
# Out:
# 100%|██████████| 91/91 [00:00<00:00, 24030.83it/s]
#   0%|          | 0/91 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ee89874a87f5> in <module>
#       1 a = CFG_getdict_lists(gt_dicts_list,preds_dicts,field_names)
# ----> 2 compute_text_metrics(a,field_names)
#
# ~/ai-science-di-metrics/di-metrics/metrics/metric_utils.py in compute_text_metrics(doc_predact_list_p, fields_p)
#      79         for field in fields_p:
#      80             #try:
# ---> 81             lcseq = lcsubsequence_dp(str(gt_dict[field]),str(pred_dict[field]))
#      82             lcstr = lcsubsstring_dp(str(gt_dict[field]),str(pred_dict[field]))
#      83             # except:
#
# KeyError: 'NjPartIiPartnerContributionA'

# %% [markdown]
# #### Get dict lists and computer metrics

# %%
cfg_master_dict = compute_text_metrics(CFG_getdict_lists(gt_dicts_list,preds_dicts,field_names),field_names)
cfg_master_dict

# %% [markdown]
# #### Output CFG to DF

# %%
# Table contains full set of all file Id, all classes
column_names = ['FileID','Filename','FieldName','String_Actual','String_Predict','Box_Actual','Box_Predict']
cky_eval_df = pd.DataFrame(columns = column_names)
cky_eval_df.head()

# %%
gt_df = pd.DataFrame(gt_list)
pred_df = pd.DataFrame(pred_list)
gt_df = gt_df.rename(columns={'text':'gt_text'}).drop(columns=['bbox', 'page'])
pred_df = pred_df.rename(columns={'text':'pred_text'}).drop(columns=['bbox', 'page'])
text_df = pd.merge(gt_df, pred_df, on=['label', 'file'])
# text_df = text_df.drop(columns=['label', 'file'b])

# %%
print("Direct Match Accuracy:", sum(text_df['gt_text'] == text_df['pred_text']) / len(text_df))

# %%
text_df['direct'] = (text_df['gt_text'] == text_df['pred_text']).astype(float)
text_df.head()

# %%
pattern = re.compile('[\W_]+')
text_df["pred_text_lower"] = text_df["pred_text"].apply(lambda x: pattern.sub('',x).lower())
text_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ad7d34a7aa4d> in <module>
# ----> 1 pattern = re.compile('[\W_]+')
#
# NameError: name 're' is not defined

# %%
text_df["gt_text_lower"] = text_df["gt_text"].apply(lambda x: pattern.sub('',x).lower())
text_df['direct_lower'] = (text_df['gt_text_lower'] == text_df['pred_text_lower']).astype(float)

# %%
text_df['levenshtein'] = text_df.apply(lambda x: levenshteinDistance(x['gt_text'], x['pred_text']), axis=1)

# %%
text_df['levenshtein_lower'] = text_df.apply(lambda x: levenshteinDistance(x['gt_text_lower'], x['pred_text_lower']), axis=1)

# %%
print("Field accuracies:")
text_df.describe()

# %% [markdown]
# # LayoutLM

# %% [markdown]
# LayoutLM outputs with an unconstrained softmax/logistic regression, assigning a class label for each bounding box it does inference with. As the model is not constrained and can produce multiple outputs of same class for one sequence/page.
#
# We develop a naive implementation to test the LayoutLM token classification model (NER) on slot filling task, by simply taking the first instance we findof the predicted class as iterate through the output list of predictions.

# %%
#Trivial example
from seqeval.metrics.sequence_labeling import get_entities
class_list = ['O','S-Address']
seq_dict = {}
seq1 = ['S-Address', 'S-PartnerEIN', 'S-PartnerName', 'S-Address']
seq_spans = get_entities(seq1)
for i,j in zip(seq1, seq_spans):
    if i not in seq_dict.keys():
        seq_dict[i] = j[1:3]
print(seq1, len(seq1))
print((seq_spans), len(seq_spans))
print((seq_dict), len(seq_dict))

# %%
# Input format for LayoutLM outputs currently is output csv/excel
layoutlm_pred_file = "/data/home/djonathan/ai-science-di-metrics/datasets/NJK1_91holdout_Pytorch_LayoutlmLinearClassifier/NJ_K1_Client_Data_UoA_fixed_with_BIOES_orig_test_csv_with_predictions_LD.xlsm"
layoutlm_pred_df = pd.read_excel(layoutlm_pred_file, index_col=0,sheet_name='raw') 
layoutlm_pred_df.head()

# %%
field_names = list(set(layoutlm_pred_df['Profile_Map_Name']))
field_names

# %% [markdown]
# #### Make dict of retreived predicted vs actual values for LayoutLM.

# %%
output_dict = {}
g = list(layoutlm_pred_df.groupby('sentence_id').groups.values())
sentence_id_list = layoutlm_pred_df.groupby('sentence_id').groups.keys()
dflist = (layoutlm_pred_df.loc[x] for x in g)

for df_,sent_id in zip(dflist,sentence_id_list):
    gt_list, pred_list = [], []
    
    gt_index_list = get_entities(list(df_['labels'].replace(np.nan, 'O', regex=True)))
    pred_index_list = get_entities(list(df_['Predicted_Map_Name'].replace(np.nan, 'O', regex=True)))
    
    for i,j in zip(gt_index_list,pred_index_list):
        gt_list.append([list(i)[0],df_['words'].iloc[i[1]]])
        pred_list.append([list(j)[0],df_['words'].iloc[j[1]]])
        
    output_dict[sent_id] = gt_list,pred_list


# for df_,sent_id in zip(dflist,sentence_id_list):
#     gt_list, pred_list = [], []
#     gt_index_list = get_entities(list(df_['labels'].replace(np.nan, 'O', regex=True)))
#     pred_index_list = get_entities(list(df_['Predicted_Map_Name'].replace(np.nan, 'O', regex=True)))
#     for i,j in zip(gt_index_list,pred_index_list):
#         gt_list.append([list(i),df_['words'].iloc[i[1]],df_['labels'].iloc[i[1]]])
#         pred_list.append([list(j),df_['words'].iloc[j[1]],df_['labels'].iloc[j[1]]])
        
#     output_dict[sent_id] = [gt_list,pred_list]
    
output_dict['5e9e96bd05a1d2043eeccd31_12'][0]

# %%
output_dict['5e9e96bd05a1d2043eeccd31_12'][1]

# %% [markdown]
# ### Output LayoutLM to DF

# %%
column_names = ['FileID','Filename','FieldName','String_Actual','String_Predict','Box_Actual','Box_Predict']
layoutlm_eval_df = pd.DataFrame()
index_list = []
for count, i in enumerate(sentence_id_list):
    for j in field_names:
        index_list.append([i,j])
assert len(index_list) == len(field_names) *len(sentence_id_list)

# %%
layoutlm_eval_df['FileID'] = [i[0] for i in index_list]
layoutlm_eval_df['FieldName'] = [i[1] for i in index_list]
layoutlm_eval_df['Predicted'] = ''
layoutlm_eval_df['Actual'] = ''

# %%
layoutlm_eval_df.head()

# %%
pred_list_df = []
count = 0
for i,j in enumerate(layoutlm_eval_df['FileID']):
    file_gts = output_dict[layoutlm_eval_df.iloc[count]['FileID']][0]
    pred_gts = output_dict[layoutlm_eval_df.iloc[count]['FileID']][1]
    
    count +=1
        
    

pred_gts

# %%
file_dict
